# %%
# !pip install librosa
# !apt-get update
# something else to fix error when importing librosa may need to go here
# Out:
# Requirement already satisfied: librosa in /opt/conda/envs/fastai/lib/python3.6/site-packages (0.7.1)
# Requirement already satisfied: numba>=0.43.0 in /opt/conda/envs/fastai/lib/python3.6/site-packages (from librosa) (0.46.0)
# Requirement already satisfied: scipy>=1.0.0 in /opt/conda/envs/fastai/lib/python3.6/site-packages (from librosa) (1.2.0)
# Requirement already satisfied: decorator>=3.0.0 in /opt/conda/envs/fastai/lib/python3.6/site-packages (from librosa) (4.3.0)
# Requirement already satisfied: resampy>=0.2.2 in /opt/conda/envs/fastai/lib/python3.6/site-packages (from librosa) (0.2.2)
# Requirement already satisfied: audioread>=2.0.0 in /opt/conda/envs/fastai/lib/python3.6/site-packages (from librosa) (2.1.8)
# Requirement already satisfied: numpy>=1.15.0 in /opt/conda/envs/fastai/lib/python3.6/site-packages (from librosa) (1.15.4)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /opt/conda/envs/fastai/lib/python3.6/site-packages (from librosa) (0.22)
# Requirement already satisfied: six>=1.3 in /opt/conda/envs/fastai/lib/python3.6/site-packages (from librosa) (1.12.0)
# Requirement already satisfied: joblib>=0.12 in /opt/conda/envs/fastai/lib/python3.6/site-packages (from librosa) (0.14.1)
# Requirement already satisfied: soundfile>=0.9.0 in /opt/conda/envs/fastai/lib/python3.6/site-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: llvmlite>=0.30.0dev0 in /opt/conda/envs/fastai/lib/python3.6/site-packages (from numba>=0.43.0->librosa) (0.30.0)
# Requirement already satisfied: cffi>=1.0 in /opt/conda/envs/fastai/lib/python3.6/site-packages (from soundfile>=0.9.0->librosa) (1.11.5)
# Requirement already satisfied: pycparser in /opt/conda/envs/fastai/lib/python3.6/site-packages (from cffi>=1.0->soundfile>=0.9.0->librosa) (2.19)
# Ign:1 http://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64  InRelease
# Hit:2 http://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64  Release
# Ign:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1604/x86_64  InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1604/x86_64  Release
# Get:7 http://security.ubuntu.com/ubuntu xenial-security InRelease [109 kB]
# Hit:8 http://archive.ubuntu.com/ubuntu xenial InRelease
# Get:9 http://archive.ubuntu.com/ubuntu xenial-updates InRelease [109 kB]
# Get:10 http://archive.ubuntu.com/ubuntu xenial-backports InRelease [107 kB]
# Fetched 325 kB in 1s (179 kB/s)
# Reading package lists... Done

# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

path = Path.cwd(); print(path)
# Out:
# /notebooks/music-genre-classification

# %% [markdown]
# ## Downloading and Extracting Data

# %%
import requests
import sys

import tarfile

# %%
def download(url, filename):
    with open(filename, 'wb') as f:
        response = requests.get(url, stream=True)
        total = response.headers.get('content-length')
        
        print(f"Downloading file of size {round(total/1e6, 1)} MB")
        if total is None:
            f.write(response.content)
        else:
            downloaded = 0
            total = int(total)
            for data in response.iter_content(chunk_size=max(int(total/1000), 1024*1024)):
                downloaded += len(data)
                f.write(data)
                done = int(50*downloaded/total)
                sys.stdout.write('\r[{}{}]'.format('█' * done, '.' * (50-done)))
                sys.stdout.flush()
    sys.stdout.write('\n')

url = 'http://opihi.cs.uvic.ca/sound/genres.tar.gz'
target_path = path/"genres.tar.gz"
download(url, target_path)
# Out:
# [██████████████████████████████████████████████████]

# %%
def extract_t_gz(path_in, path_out):
    if (path_in.endswith("tar.gz")):
        tar = tarfile.open(path_in, "r:gz")
        tar.extractall(path=path_out)
        tar.close()
    elif (path_in.endswith("tar")):
        tar = tarfile.open(path_in, "r:")
        tar.extractall(path=path_out)
        tar.close()

extract_t_gz(str(target_path), str(path/'data'))

# %% [markdown]
# ## Exploring Data

# %%
import librosa
import IPython.display

# %%
# data folders
data_folder = path/'data'/'genres'

genre_folders = [file for file in data_folder.iterdir() if file.is_dir()]; genre_folders
# Out:
# [PosixPath('/notebooks/music-genre-classification/data/genres/reggae'),
#  PosixPath('/notebooks/music-genre-classification/data/genres/jazz'),
#  PosixPath('/notebooks/music-genre-classification/data/genres/country'),
#  PosixPath('/notebooks/music-genre-classification/data/genres/pop'),
#  PosixPath('/notebooks/music-genre-classification/data/genres/blues'),
#  PosixPath('/notebooks/music-genre-classification/data/genres/rock'),
#  PosixPath('/notebooks/music-genre-classification/data/genres/hiphop'),
#  PosixPath('/notebooks/music-genre-classification/data/genres/classical'),
#  PosixPath('/notebooks/music-genre-classification/data/genres/metal'),
#  PosixPath('/notebooks/music-genre-classification/data/genres/disco')]

# %%
import librosa
import librosa.display

def read_audio(pathname):
    y, sr = librosa.load(pathname, sr=44100)
    return y

def audio_to_melspectrogram(audio):
    spectrogram = librosa.feature.melspectrogram(audio, 
                                                 sr=44100,
                                                 #n_mels=conf.n_mels,
                                                 #hop_length=conf.hop_length,
                                                 #n_fft=conf.n_fft,
                                                 #fmin=conf.fmin,
                                                 #fmax=conf.fmax
                                                )
    spectrogram = librosa.power_to_db(spectrogram)
    spectrogram = spectrogram.astype(np.float32)
    return spectrogram

def show_melspectrogram(mels, title='Log-frequency power spectrogram'):
    librosa.display.specshow(mels, x_axis='time', y_axis='mel', 
                             sr='44100'#, hop_length=conf.hop_length,
                            #fmin=conf.fmin, fmax=conf.fmax
                            )
    plt.colorbar(format='%+2.0f dB')
    plt.title(title)
    plt.show()

def read_as_melspectrogram(pathname, debug_display=False):
    x = read_audio(pathname)
    mels = audio_to_melspectrogram(x)
    if debug_display:
        IPython.display.display(IPython.display.Audio(x, rate=44100))
        show_melspectrogram(mels)
    return mels

# %%
reggae_files = [file for file in genre_folders[0].iterdir()]
spec = read_as_melspectrogram(reggae_files[0], debug_display=True)
show_melspectrogram(spec)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
